# %% [markdown]
# Name: Peishan Huang Github Username: peishanhuang USC ID: 7777529178

# %%
import pandas as pd
import numpy as np
import random
import statistics as stat

# %% [markdown]
# Question 1(b)

# %%
te_files=['bending1/dataset1.csv','bending1/dataset2.csv','bending2/dataset1.csv','bending2/dataset2.csv',
          'cycling/dataset1.csv','cycling/dataset2.csv','cycling/dataset3.csv','lying/dataset1.csv',
         'lying/dataset2.csv','lying/dataset3.csv','sitting/dataset1.csv','sitting/dataset2.csv',
         'sitting/dataset3.csv','standing/dataset1.csv','standing/dataset2.csv','standing/dataset3.csv',
         'walking/dataset1.csv','walking/dataset2.csv','walking/dataset3.csv']

tr_files=['bending1/dataset3.csv','bending1/dataset4.csv','bending1/dataset5.csv','bending1/dataset6.csv','bending1/dataset7.csv',
         'bending2/dataset3.csv','bending2/dataset4.csv','bending2/dataset5.csv','bending2/dataset6.csv',
         'cycling/dataset4.csv','cycling/dataset5.csv','cycling/dataset6.csv','cycling/dataset7.csv','cycling/dataset8.csv',
         'cycling/dataset9.csv','cycling/dataset10.csv','cycling/dataset11.csv','cycling/dataset12.csv','cycling/dataset13.csv',
         'cycling/dataset14.csv','cycling/dataset15.csv','lying/dataset4.csv','lying/dataset5.csv','lying/dataset6.csv',
         'lying/dataset7.csv','lying/dataset8.csv','lying/dataset9.csv','lying/dataset10.csv','lying/dataset11.csv','lying/dataset12.csv',
         'lying/dataset13.csv','lying/dataset14.csv','lying/dataset15.csv','sitting/dataset4.csv','sitting/dataset5.csv',
         'sitting/dataset6.csv','sitting/dataset7.csv','sitting/dataset8.csv','sitting/dataset9.csv','sitting/dataset10.csv','sitting/dataset11.csv',
         'sitting/dataset12.csv','sitting/dataset13.csv','sitting/dataset14.csv','sitting/dataset15.csv','standing/dataset4.csv',
         'standing/dataset5.csv','standing/dataset6.csv','standing/dataset7.csv','standing/dataset8.csv','standing/dataset9.csv','standing/dataset10.csv',
         'standing/dataset11.csv','standing/dataset12.csv','standing/dataset13.csv','standing/dataset14.csv','standing/dataset15.csv','walking/dataset4.csv',
         'walking/dataset5.csv','walking/dataset6.csv','walking/dataset7.csv','walking/dataset8.csv','walking/dataset9.csv','walking/dataset10.csv',
         'walking/dataset11.csv','walking/dataset12.csv','walking/dataset13.csv','walking/dataset14.csv','walking/dataset15.csv']


te_dfs=[]
tr_dfs=[]

for file in te_files:
    path=f'../data/{file}'
    df=pd.read_csv(path,header=4,on_bad_lines='skip')
    te_dfs.append(df)

for file in tr_files:
    path=f'../data/{file}'
    df=pd.read_csv(path,header=4,on_bad_lines='skip')
    tr_dfs.append(df)

testset=pd.concat(te_dfs,ignore_index=True)
trainset=pd.concat(tr_dfs,ignore_index=True)


pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)

trainset
testset
# Out:
#       # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  var_rss23
# 0                   0      39.25       0.43      22.75       0.43      33.75       1.30
# 1                 250      39.25       0.43      23.00       0.00      33.00       0.00
# 2                 500      39.25       0.43      23.25       0.43      33.00       0.00
# 3                 750      39.50       0.50      23.00       0.71      33.00       0.00
# 4                1000      39.50       0.50      24.00       0.00      33.00       0.00
# ...               ...        ...        ...        ...        ...        ...        ...
# 9115           118750      36.00       2.45      17.00       5.10      20.50       0.87
# 9116           119000      34.33       1.89      15.00       2.45      17.00       2.12
# 9117           119250      33.00       7.35      14.60       3.14      13.00       5.70
# 9118           119500      31.67       1.25      11.00       6.16      19.25       2.17
# ...

# %% [markdown]
# Question 1(c)i

# %% [markdown]
# Types of time-domain features are usually used in time series classification include finding the minimum, maximum, mean, median, standard deviation, first quartile, and third quartile values.

# %% [markdown]
# Question 1(c)ii

# %%
all_files=['bending1/dataset1.csv','bending1/dataset2.csv','bending2/dataset1.csv','bending2/dataset2.csv',
          'cycling/dataset1.csv','cycling/dataset2.csv','cycling/dataset3.csv','lying/dataset1.csv',
         'lying/dataset2.csv','lying/dataset3.csv','sitting/dataset1.csv','sitting/dataset2.csv',
         'sitting/dataset3.csv','standing/dataset1.csv','standing/dataset2.csv','standing/dataset3.csv',
         'walking/dataset1.csv','walking/dataset2.csv','walking/dataset3.csv','bending1/dataset3.csv','bending1/dataset4.csv','bending1/dataset5.csv','bending1/dataset6.csv','bending1/dataset7.csv',
         'bending2/dataset3.csv','bending2/dataset4.csv','bending2/dataset5.csv','bending2/dataset6.csv',
         'cycling/dataset4.csv','cycling/dataset5.csv','cycling/dataset6.csv','cycling/dataset7.csv','cycling/dataset8.csv',
         'cycling/dataset9.csv','cycling/dataset10.csv','cycling/dataset11.csv','cycling/dataset12.csv','cycling/dataset13.csv',
         'cycling/dataset14.csv','cycling/dataset15.csv','lying/dataset4.csv','lying/dataset5.csv','lying/dataset6.csv',
         'lying/dataset7.csv','lying/dataset8.csv','lying/dataset9.csv','lying/dataset10.csv','lying/dataset11.csv','lying/dataset12.csv',
         'lying/dataset13.csv','lying/dataset14.csv','lying/dataset15.csv','sitting/dataset4.csv','sitting/dataset5.csv',
         'sitting/dataset6.csv','sitting/dataset7.csv','sitting/dataset8.csv','sitting/dataset9.csv','sitting/dataset10.csv','sitting/dataset11.csv',
         'sitting/dataset12.csv','sitting/dataset13.csv','sitting/dataset14.csv','sitting/dataset15.csv','standing/dataset4.csv',
         'standing/dataset5.csv','standing/dataset6.csv','standing/dataset7.csv','standing/dataset8.csv','standing/dataset9.csv','standing/dataset10.csv',
         'standing/dataset11.csv','standing/dataset12.csv','standing/dataset13.csv','standing/dataset14.csv','standing/dataset15.csv','walking/dataset4.csv',
         'walking/dataset5.csv','walking/dataset6.csv','walking/dataset7.csv','walking/dataset8.csv','walking/dataset9.csv','walking/dataset10.csv',
         'walking/dataset11.csv','walking/dataset12.csv','walking/dataset13.csv','walking/dataset14.csv','walking/dataset15.csv']
min1_ls=[]
max1_ls=[]
mean1_ls=[]
median1_ls=[]
SD1_ls=[]
first_quart1_ls=[]
third_quart1_ls=[]
min2_ls=[]
max2_ls=[]
mean2_ls=[]
median2_ls=[]
SD2_ls=[]
first_quart2_ls=[]
third_quart2_ls=[]
min3_ls=[]
max3_ls=[]
mean3_ls=[]
median3_ls=[]
SD3_ls=[]
first_quart3_ls=[]
third_quart3_ls=[]
min4_ls=[]
max4_ls=[]
mean4_ls=[]
median4_ls=[]
SD4_ls=[]
first_quart4_ls=[]
third_quart4_ls=[]
min5_ls=[]
max5_ls=[]
mean5_ls=[]
median5_ls=[]
SD5_ls=[]
first_quart5_ls=[]
third_quart5_ls=[]
min6_ls=[]
max6_ls=[]
mean6_ls=[]
median6_ls=[]
SD6_ls=[]
first_quart6_ls=[]
third_quart6_ls=[]


for file in all_files:
    path=f'../data/{file}'
    df=pd.read_csv(path,header=4,on_bad_lines='skip')
    
    min1=df['avg_rss12'].min()
    max1=df['avg_rss12'].max()
    mean1=df['avg_rss12'].mean()
    median1=df['avg_rss12'].median()
    SD1=df['avg_rss12'].std()
    first_quart1=df['avg_rss12'].quantile(0.25)
    third_quart1=df['avg_rss12'].quantile(0.75)
    min1_ls.append(min1)
    max1_ls.append(max1)
    mean1_ls.append(mean1)
    median1_ls.append(median1)
    SD1_ls.append(SD1)
    first_quart1_ls.append(first_quart1)
    third_quart1_ls.append(third_quart1)

    min2=df['var_rss12'].min()
    max2=df['var_rss12'].max()
    mean2=df['var_rss12'].mean()
    median2=df['var_rss12'].median()
    SD2=df['var_rss12'].std()
    first_quart2=df['var_rss12'].quantile(0.25)
    third_quart2=df['var_rss12'].quantile(0.75)
    min2_ls.append(min2)
    max2_ls.append(max2)
    mean2_ls.append(mean2)
    median2_ls.append(median2)
    SD2_ls.append(SD2)
    first_quart2_ls.append(first_quart2)
    third_quart2_ls.append(third_quart2)
     
    min3=df['avg_rss13'].min()
    max3=df['avg_rss13'].max()
    mean3=df['avg_rss13'].mean()
    median3=df['avg_rss13'].median()
    SD3=df['avg_rss13'].std()
    first_quart3=df['avg_rss13'].quantile(0.25)
    third_quart3=df['avg_rss13'].quantile(0.75)
    min3_ls.append(min3)
    max3_ls.append(max3)
    mean3_ls.append(mean3)
    median3_ls.append(median3)
    SD3_ls.append(SD3)
    first_quart3_ls.append(first_quart3)
    third_quart3_ls.append(third_quart3)
    
    min4=df['var_rss13'].min()
    max4=df['var_rss13'].max()
    mean4=df['var_rss13'].mean()
    median4=df['var_rss13'].median()
    SD4=df['var_rss13'].std()
    first_quart4=df['var_rss13'].quantile(0.25)
    third_quart4=df['var_rss13'].quantile(0.75)
    min4_ls.append(min4)
    max4_ls.append(max4)
    mean4_ls.append(mean4)
    median4_ls.append(median4)
    SD4_ls.append(SD4)
    first_quart4_ls.append(first_quart4)
    third_quart4_ls.append(third_quart4)
    
    min5=df['avg_rss23'].min()
    max5=df['avg_rss23'].max()
    mean5=df['avg_rss23'].mean()
    median5=df['avg_rss23'].median()
    SD5=df['avg_rss23'].std()
    first_quart5=df['avg_rss23'].quantile(0.25)
    third_quart5=df['avg_rss23'].quantile(0.75)
    min5_ls.append(min5)
    max5_ls.append(max5)
    mean5_ls.append(mean5)
    median5_ls.append(median5)
    SD5_ls.append(SD5)
    first_quart5_ls.append(first_quart5)
    third_quart5_ls.append(third_quart5)
    
    min6=df['var_rss23'].min()
    max6=df['var_rss23'].max()
    mean6=df['var_rss23'].mean()
    median6=df['var_rss23'].median()
    SD6=df['var_rss23'].std()
    first_quart6=df['var_rss23'].quantile(0.25)
    third_quart6=df['var_rss23'].quantile(0.75)
    min6_ls.append(min6)
    max6_ls.append(max6)
    mean6_ls.append(mean6)
    median6_ls.append(median6)
    SD6_ls.append(SD6)
    first_quart6_ls.append(first_quart6)
    third_quart6_ls.append(third_quart6)
    
    
list=[min1_ls,max1_ls,mean1_ls,median1_ls,SD1_ls,first_quart1_ls,third_quart1_ls,min2_ls,max2_ls,mean2_ls,median2_ls,
     SD2_ls,first_quart2_ls,third_quart2_ls,min3_ls,max3_ls,mean3_ls,median3_ls,SD3_ls,first_quart3_ls,third_quart3_ls,
      min4_ls,max4_ls,mean4_ls,median4_ls,SD4_ls,first_quart4_ls,third_quart4_ls,min5_ls,max5_ls,mean5_ls,median5_ls,
      SD5_ls,first_quart5_ls,third_quart5_ls,min6_ls,max6_ls,mean6_ls,median6_ls,SD6_ls,first_quart6_ls,third_quart6_ls]
df = pd.DataFrame({'min1':list[0],'max1':list[1],'mean1':list[2],'median1':list[3],'SD1':list[4],'first_quart1':list[5],
                  'third_quart1':list[6],'min2':list[7],'max2':list[8],'mean2':list[9],'median2':list[10],'SD2':list[11],
                  'first_quart2':list[12],'third_quart2':list[13],'min3':list[14],'max3':list[15],'mean3':list[16],
                  'median3':list[17],'SD3':list[18],'first_quart3':list[19],'third_quart3':list[20],'min4':list[21],
                  'max4':list[22],'mean4':list[23],'median4':list[24],'SD4':list[25],'first_quart4':list[26],
                   'third_quart4':list[27],'min5':list[28],'max5':list[29],'mean5':list[30],'median5':list[31],'SD5':list[32],
                   'first_quart5':list[33],'third_quart5':list[34],'min6':list[35],'max6':list[36],'mean6':list[37],'median6':list[38],
                   'SD6':list[39],'first_quart6':list[40],'third_quart6':list[41]})

pd.set_option('display.max_rows',5000)
pd.set_option('display.max_columns',5000)
pd.set_option('display.width',5000)
df
# Out:
#      min1   max1      mean1  median1       SD1  first_quart1  third_quart1  min2   max2     mean2  median2       SD2  first_quart2  third_quart2  min3   max3      mean3  median3       SD3  first_quart3  third_quart3  min4   max4     mean4  median4       SD4  first_quart4  third_quart4   min5   max5      mean5  median5       SD5  first_quart5  third_quart5  min6   max6     mean6  median6       SD6  first_quart6  third_quart6
# 0   37.25  45.00  40.624792   40.500  1.476967       39.2500       42.0000   0.0   1.30  0.358604    0.430  0.322605        0.0000        0.5000  4.00  29.50  19.040937   19.250  4.462952       16.0000       23.2500   0.0   7.23  0.832542    0.500  0.965659        0.0000        1.1200  27.25  38.25  34.311292   35.000  2.188449       33.0000       36.0000  0.00   1.92  0.570583    0.430  0.582915        0.0000        1.3000
# ...

# %% [markdown]
# Question 1(c)iii

# %%
std=df.std()
boot_statistic=[]
CIs=[]
for i in df.columns:
    each_column=df[i]
    values=each_column.values
    for i in range(100):
        boot_sample=random.choices(values,k=88)
        boot_std=stat.stdev(boot_sample)
        boot_statistic.append(boot_std)
        while len(boot_statistic)==100:
            boot_statistic.sort()
            CI=[boot_statistic[5],boot_statistic[94]]
            CIs.append(CI)
            boot_statistic=[]

s1=pd.Series(std).reset_index()
s2=pd.Series(CIs)

print('The estimated standard deviation of each time-domain features is:\n',s1)
print('\n')
print('The 90% bootstrap confident interval for the standard deviation of each features is:\n',s2)
# Out:
# The estimated standard deviation of each time-domain features is:
#             index         0
# 0           min1  9.569975
# 1           max1  4.394362
# 2          mean1  5.335700
# 3        median1  5.440054
# 4            SD1  1.772185
# 5   first_quart1  6.153874
# 6   third_quart1  5.138925
# 7           min2  0.000000
# 8           max2  5.062729
# 9          mean2  1.574198
# 10       median2  1.412293
# 11           SD2  0.884137
# 12  first_quart2  0.946386
# 13  third_quart2  2.125399
# 14          min3  2.956462
# 15          max3  4.875137
# 16         mean3  4.008228
# 17       median3  4.036396
# 18           SD3  0.946670
# 19  first_quart3  4.220658
# 20  third_quart3  4.171628
# 21          min4  0.000000
# 22          max4  2.183625
# 23         mean4  1.166178
# 24       median4  1.145985
# 25           SD4  0.458283
# 26  first_quart4  0.843405
# 27  third_quart4  1.552504
# 28          min5  6.124001
# 29          max5  5.741238
# 30         mean5  5.675543
# ...

# %% [markdown]
# Question 1(c)iv

# %% [markdown]
# The three most important features I choose are min, mean, and max. Because these three can help me easily understand the extremers and the average of a set of data.

# %% [markdown]
# Question 2

# %% [markdown]
# (a)We would expect the training RSS for the cubic regression to be smaller. Althought the true relationship between X and Y is linear, adding one more term in the model will reduce (or at least not increase) the RSS.
# (b)We would expect the testing RSS for the cubic regression to be greater than linear one.  Because the polynomial model tends to overfit the data, thereby increase the variance of the model.
# (c)We would expect the training RSS for the cubic regression would be lower because of higher flexibility of the model making the model fitted the data better, thereby decrease the bias and increase the variance.
# (d)There is not enough information to tell since we don't know the true relationship is how far from the linear regression. If it's not far and closer to the linear way, then the testing RSS will be lower than the cubic, or if it's closer to cubic, then the testing RSS will be lower in cubic than in linear.

# %% [markdown]
# Reference:
# 1.df_std:https://www.statology.org/pandas-standard-deviation/
# 2.bootstrapped:https://online.stat.psu.edu/stat500/book/export/html/619
